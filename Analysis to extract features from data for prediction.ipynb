# %%
#these are all the modules we will be using 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data set
df=pd.read_csv('Cars_Dataset.csv')
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using regression plots.
#
# This plot will show a combination of a scattered data points (a scatterplot), as well as the fitted linear regression line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).
#
# Let's visualize highway-mpg as predictor variable of price:

# %%
width=8
height=6
plt.figure(figsize=(width,height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.title('Correlation of highway-mpg and price by Idris')
# Out:
# Text(0.5, 1.0, 'Correlation of highway-mpg and price by Idris')

# %% [markdown]
# We can see from this plot that price is negatively correlated to highway-mpg since the regression slope is negative.
# We can use highway-mpg for prediction it is good feature for predicting the price because you can see it has big impact on the price.
#
#
#
# Lets compare this plot to the regression plot of 'peak-rpm'

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='peak-rpm', y='price', data=df)
plt.title('Correlation of peak-rpm and price by Idris')
# Out:
# Text(0.5, 1.0, 'Correlation of peak-rpm and price by Idris')

# %% [markdown]
# The points for "peak-rpm" have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the "peak-rpm" increases. so using peak-rpm for prediction might not be a good feature.
# We can also use .corr() funtion to find the correaltion between different variables

# %%
df[['peak-rpm','highway-mpg','price']].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# As you can see the highway-mpg has a stronger correaltion with the price,it is approximately -0.704692 as compared to peak-rpm which is -0.058598..
#
# We can also use some other variables to find the correaltion with the price using same tecniques as used above.
#
# Lets use Enigine-Size this time.

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='engine-size',y='price',data=df)
plt.title('Correlation of engine-size and price by Idris')
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# As you can see engine size have also positive correaltion impact on price which is approximately 0.872335

# %%
plt.figure(figsize=(width,height))
sns.regplot(x='curb-weight',y='price',data=df)
plt.title('Correlation of curb-weight and price by Idris')
df[['curb-weight','price']].corr()
# Out:
#              curb-weight     price
# curb-weight     1.000000  0.834415
# price           0.834415  1.000000

# %% [markdown]
# Curb-Weight have also a positive correlation on price which is 0.834415
